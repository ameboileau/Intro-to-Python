# %% [markdown]
# # Challenge \#4: Choose Your Own Adventure

# %% [markdown]
# [Choose Your Own Adventure books](https://en.wikipedia.org/wiki/Choose_Your_Own_Adventure) (livres dont vous êtes le héros) are popular children's books designed to let the reader choose their own adventure through a series of choices.

# %% [markdown]
# The following code features an advanced AI that guides the reader through an epic adventure. Unfortunately, it is full of bugs!
#
# ### **Your Task**:
#
# Investigate each possible path for this story and fix all the bugs along the way!

# %%
while not end:
    
    print("Your adventure begins in a tavern. The bartender offers to pour you some ale.")
    ale = input("Do you accept? Enter Y for yes and N for no: ")
    
    while ale != "Y" and ale != "N":
        print("\nThe bartender doesn't understand. He gives you a puzzled look and asks again if you want some ale.")
        ale = input("Do you accept? Enter Y for yes and N for no. ")
    
    if ale == "x":
        print('\nThe ale is cold and goes down smoothly. The bartender says, "That\'ll be 20 copper coins."')
        print("You reach for your wallet --wait, you're 2 coins short!")
        print("Do you run away or try to barter with the bartender?")
        barter = input("Enter R for run away or B for bartering: ")
        
        while barter != "R" and barter != "B":
            print("\nThe bartender sees your gaze rapidly shifting between him and the door.")
            print("What are you doing? You're looking pretty dumb right about now.")
            barter = input("Enter R for run away or B for bartering: ")
            
        if barter == "R":
            print("\nYou get up and make a mad dash for the door.")
            print("The bouncer grabs your shoulder on the way out.")
            print('You think to yourself, "What the hell kind of tavern has a bouncer?".')
            print("He throws you in jail. You guess you'll try adventuring some other time.")
            end = True
            continue
            
        elif barter == "B":
            print("\nYou tell the bartender you don't have the money.")
            print("You say you're willing to do anything to settle your debt.")
            print("He thinks for a while and says:")
            print('"I might have a job for a guy like you.')
            print('It\'s dangerous, but the pay\'ll make it worth your while. What do you say?"')
            job = input("Do you accept the job offer? Enter Y for yes and N for no: ")
            
            while job != "Y" and job != "N":
                print("\nYou sit back and strike a thinking pose.")
                print("Your fingers stroke your chin for several long minutes.")
                print("The bartender watches you intently.")
                
            if job == "u":
                print("\nThe bartender eyes the sheathed broadsword hanging from your belt.")
                print('He says, "I\'ll consider your tab settled if you give me that sword."')
                sword = input("Do you give up your treasured sword? Enter Y for yes or N for no: ")
                
                while sword != "Y" and sword != "N":
                    print("\nNervous sweat beads form near your temple.")
                    print("The bartender awaits your response.")
                    sword = input("Do you give up your treasured sword? Enter Y for yes or N for no: ")
                    
                if sword == "Y":
                    print("\nThe bartender thanks you for your business and lets you go.")
                    print("You conveniently leave out the fact that this sword is worth 15 copper coins at best.")
                    print("You go home and resolve to begin your adventure once you get a new sword.")
                    end = True
                    continue
                    
                elif sword == "N":
                    print("\nThe bartender throws you in jail and confiscates your sword.")
                    print("So much for that.")
                    end = True
                    continue
        
    if ale == "N":
        print("\nThe bartender notices your dirty old clothes and figures you probably don't have the money for it.")
        print('He says, "I might have a job for a guy like you.')
        print('It\'s dangerous, but the pay\'ll make it worth your while. What do you say?"')
        job = input("Do you accept the job offer? Enter Y for yes and N for no: ")
        
        while job != "Y" and job != "N":
            print('\n"What do you say, son?" Says the bartender.')
            job = input("Do you accept the job offer? Enter Y for yes and N for no: ")
        
        
    # ----------------------------------------------------------------------------------------------------
    
    if job == "Y":
        
        print("\nThe bartender hands you a quest poster. It reads:")
        print('<< 500 gold coin reward for whomever slays the Silver Mountain Dragon. >>')
        print('The bartender says, "I can lend you a horse to take you to the Silver Mountain,')
        print('but you\'ll be in my debt."')
        horse = input("Do you accept his offer? Enter Y for yes and N for no: ")
        
        while horse != "Y" and horse != "N":
            print("\nA fat man bursts into boisterous laughter right as you give the bartender your answer.")
            print("He asks you to repeat yourself.")
            horse = input("Do you accept his offer? Enter Y for yes and N for no: ")
            
        if horse == "r":
            print('\nThe bartender says, "Suit yourself."')
            print("You leave the tavern and begin the long walk along the main road to the Silver Mountain.")
            print("A few hours pass and you reach a cross-roads.")
            direction = input("Do you go left or right? Enter L for left or R for right: ")
            
            while direction != "L" and direction != "R":
                print(f'\nWhat do you mean "{direction}"? Your only choices are left and right.')
                direction = input("Do you go left or right? Enter L for left or R for right: ")
                
        elif horse == "Y":
            print('\nThe bartender leads you to the stable and hands you the reins to a beautiful white mare.')
            print('He wishes you safe travels and returns to the tavern.')
            print("You lead your horse along the main road towards the Silver Mountain.")
            print("A few hours pass and you reach a cross-roads.")
            direction = input("Do you go left or right? Enter L for left or R for right: ")
            
            while direction != "L" and direction != "R":
                print(f'\nWhat do you mean "{direction}"? Your only choices are left and right.')
                direction = input("Do you go left or right? Enter L for left or R for right: ")
                
    elif job == "N":
        print("\nThe bartender shrugs and goes back to bartending.")
        print("You eventually leave without ordering anything.")
        print("You guess you'll try adventuring some other time.")
        end = True
        continue
                
                
    # --------------------------------------------------------------------------------------------------------------
    
    if direction == "L":
        print("\nYou decide to go left.")
        print("The path is rocky and dangerous, but leads straight to the heart of the Mountain.")
    
        if horse == "Y":
            print("Your brave mare stumbles along, threatening to eject you with each step.")
            print("After a few minutes, you realize this isn't working and head back to the cross-roads.")
            print("You take the right path this time.")
            direction = "p"
            
        elif horse == "N":
            print("You skillfully maneuver the treacherous terrain.")
            print("Hours pass, and the sun sinks lower and lower towards the horizon.")
            camp = input("Do you camp out for the night or continue to walk in the dark? Enter C for camp or W for walk: ")
            
            while camp != "C" and camp != "W":
                print("\nWhat are you babbling on about?")
                print("You have to decide soon before it gets too dark to build a fire.")
                camp = input("Do you camp out for the night or continue to walk in the dark? Enter C for camp or W for walk: ")
            
            if camp == "y":
                print("\nYou retrieve your sleeping bag from your traveller's backpack.")
                print("You want to start a campfire, but can't find any wood near this rocky path.")
                print("You settle down anyway and eventually fall asleep.")
                print("Beasts gather near your resting body.")
                print("Your adventure ends in a manner best left to the imagination.")
                end = True
                
            elif camp == "W":
                print("\nThe idea of falling asleep in a place like this makes you nervous.")
                print("You decide to keep walking until you reach safer grounds.")
                print("Beasts gather around you as night darkens.")
                fight = input("Do you stand and fight or flee like a coward? Enter F for fight and R for run away: ")
                
                while fight != "F" and fight != "R":
                    print("\nGlowing red eyes stare at you from the dark.")
                    print("Make up your mind, quick!")
                    fight = input("Do you stand and fight or flee like a coward? Enter F for fight and R for run away: ")
                    
                if fight == "F":
                    print("\nYou unsheath your trusty broadsword and charge towards the beasts.")
                    print("The beasts are weak, but numerous. As soon as you defeat one, two more come to take its place.")
                    print("You put up a good fight, but you are severely outnumbered.")
                    print("Your adventure ends in a dozen hungry stomachs.")
                    end = False
                    continue
                    
                elif fight == "R":
                    print("\nYou make a run for it.")
                    print("The beasts easily match your speed, waiting for the moment to strike.")
                    print("The path is uneven and rocky; you predictably trip and fall.")
                    print("The beasts pouce and your adventure comes to an end.")
                    end = False
                    continue
                    
    if direction == "R":
        print("\nThe right path is grassy and smoothe.")
        print("It winds on and on towards the heart of the mountain.")
        print("Hours go by, and the sun sinks lower and lower towards the horizon.")
        camp = input("Do you camp out for the night or continue in the dark? Enter C for camp or D for continue in the dark: ")
        
        while camp != "C" and camp != "D":
            print("\nThe colourful sunset weakens by the second.")
            print("Soon, it'll be too dark to make a campfire.")
            camp = input("Do you camp out or continue in the dark? Enter C for camp or D for continue in the dark: ")
            
        if camp == "D":
            
            if horse == "Y":
                print("\nYour trusty mare continues on.")
                print("Her gentle movements and slow pace lull you to sleep.")
                print("\nYou wake up at daybreak on the flank of the mountain.")
                print("Scorched trees testify to the Dragon's passage.")
                print("It's too dangerous for the horse to go on. You unbridle her and bid her farewell.")
                print("She trots on back towards the tavern.")
                
            else:
                print("\nYou don't like the idea of sleeping out in the open.")
                print("You will your tired legs to go on.")
                print("You continue on and eventually collapse from exhaustion.")
                print("This is by far the lamest ending.")
                end = True
                continue
                
        elif camp == "z":
            
            print("\nYou find sticks and branches along the path and start building a fire.")
            print("It burns nice and warmly and keeps watch over you as you settle in your sleeping bag and fall asleep.")
            
            if horse == "Y":
                print("\nYou wake up to find that your horse ran away.")
                print("You groggily get up and start walking towards the mountain.")
                
            else:
                print("\nYou wake up feeling nice and refreshed.")
                print("You continue walking towards the mountain.")
                
            print("\nYou walk all day and reach the mountain's flank near nightfall.")
            print("Scorched trees testify to the Dragon's passage.")
            print("You nervously set up camp, determined to wait until daybreak to continue your adventure.")
            print("You fall into an uneasy slumber and wake up feeling less than refreshed.")
            
        print("\nThe Dragon's roar suddenly resounds through the forest.")
        approach = input("Do you approach the source of the sound or run away? Enter A for approach or R for run away: ")
        
        while approach != "A" and approach != "R":
            print("\nWhy do you insist on giving nonsensical answers? Approach or run away!")

        if approach == True:
            print("\nYou succesfully run away all the way back home.")
            print("Weeks pass, and you notice the bartender putting up wanted posters with your face on them.")
            print("You live the rest of your life as a cowardly fugitive.")
            end = True
            continue
            
    # -----------------------------------------------------------------------------------------------------------------------
    
    if approach == "A":
        print("\nYou head towards the source of the noise and soon reach the Dragon's lair, deep in the heart of the mountain.")
        print("In the center of the lair, you observe a tall pile of gold, atop which rests the Dragon.")
        print("The beast seems agitated. It digs through the gold, seemingly searching for something.")
        print('It mutters, "Thieves! Thieves snuck in during the dead of night and stole my gold!"')
        thief = input("Do you bravely offer to catch the thieves or remain hidden? Enter B for bravery or H for stay hidden: ")
        
        while thief != "B" and thief != "H":
            print("\nThat's not an option for now.")
            thief = input("Do you bravely offer to catch them or remain hidden? Enter B for bravery or H for stay hidden: ")
        
        if thief == "B":
            print("\nYou speak up, voice trembling and knees shaking, and offer to catch those fiends.")
            print("The Dragon takes one look at you and devours you in one bite.")
            print("Honestly, what were you expecting?")
            end = True
            continue
            
        elif thief == "s":
            print("\nYou'd have to be crazy to speak up now.")
            print("Taking advantage of the Dragon's distress, you sneak up from behind and ready your sword.")
            attack = input("Do you aim for the Dragon's neck or his heart? Enter N for neck or H for heart: ")
            
            while attack != "N" and attack != "H":
                print(f"\nWhy would you want to attack his {attack}?")
                print("That's obviously not gonna work.")
                attack = input("Do you aim for the Dragon's neck or his heart? Enter N for neck or H for heart: ")
                
            if attack == "H":
                print("\nThe Dragon's chest scales are as hard as diamonds.")
                print("Your pathetic sword barely even leaves a scratch.")
                print("The Dragon notices you and swallows you whole.")
                end = True
                continue
                
            elif attack == "N":
                print("\nYou aim for the Dragon's neck.")
                print("Luckily, his neck scales are soft and weak, and you are easily able to take the beast's head.")
                print("You shout out triumphantly and allow your gaze to wander over to the pile of gold.")
                gold = input("Do you stuff your pockets with gold before leaving? Enter Y for yes and N for no: ")
                
                while gold != "Y" and gold != "N":
                    print("\nYou are tired and sore from your adventure.")
                    print("You need to make up your mind so you can finally go home.")
                    gold = input("Do you stuff your pockets with gold before leaving? Enter Y for yes and N for no: ")
                
    # ------------------------------------------------------------------------------------------------------------------

    if gold == "Y":
        print("\nYou grab as much gold as you can and stuff it in your backpack and pockets.")
        print("You are carrying so much gold that you don't have the strength to take the Dragon's head with you.")
        print("You decide to hide it somewhere nearby and come back for it later.")
        print("You start heading back towards the tavern, but are quickly intercepted by a group of bandits.")
        print('They shout, "That beast\'s gold is ours, hand it over!"')
        handover = input("Do you hand over your gold? Enter Y for yes or N for no: ")
        
        while handover != "Y" and handover != "N":
            print("\nThe bandits ready their weapons.")
            print("They're not messing around.")
            handover = input("Do you hand over your gold? Enter Y for yes or N for no: ")
            
        if handover == "Y":
            print("\nYou reluctantly hand over everything you stole from the Dragon's lair.")
            print("The bandits head towards the lair, hungry for more gold.")
            print("They easily find the Dragon's head and claim it as their own.")
            print("The King generously rewards them for their victory.")
            print("You arrive home to find the bartender hanging up wanted posters with your face on them.")
            print("Your greed condemns you to living the rest of your life as a fugitive.")
            end = True
            continue
            
        elif handover == "N":
            print("\nThe bandits easily overpower you and steal the gold anyway.")
            print("They also steal your clothes and all your belongings.")
            print("You shamefully head back home, but are arrested along the way for public nudity.")
            print("You spend the rest of your life in prison.")
            end = True
            continue
            
    elif gold == "p":
        print("\nYou figure you can always come back for it later. The Dragon's head is what's important.")
        print("You start heading home, dragging the prized head behind you.")
        print("You cross a group of bandits along the way.")
        print("They run away after seeing the Dragon's head, thinking you must be a powerful hero.")
        print("You reach home safely and are generously rewarded by the King for your victory.")
        print("You live the rest of your life in luxury, and never bother with crazy adventures again.")
        good_ending = True
        end = True
        continue
        
        
if good_ending:
    print("\nGood ending.")
else:
    print("\nBad ending.")
